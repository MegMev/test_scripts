# %%
import ROOT as r
# Out:
# Module libc not found.
# Welcome to JupyROOT 6.26/10

# %%
r.EnableImplicitMT()

# %%
df=r.RDataFrame('events','megat.edm4hep.root')

# %%
reco_e=df.Histo1D('CztHits.energy')

# %%
reco_e.Draw()
# Out:
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
r.c1.Draw()
